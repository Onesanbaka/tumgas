# %% [markdown]
# <a href="https://colab.research.google.com/github/Onesanbaka/tumgas/blob/main/Practice/Modul_1-3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practicum Modules 1-3: Python Fundamentals, Control Flow, and Strings
#
# **Difficulty:** Easy module
# **Estimated time:** 180 minutes
# **Environment:** Python 3.10+

# %% [markdown]
# ## How to use this notebook
#
# 1. Run each review cell from top to bottom.
# 2. Read the value of every variable before changing the starter code.
# 3. Replace every `TODO` value or `pass` statement with your implementation.
# 4. Run the validation cell below each task.
# 5. Do not edit the validation cells.
# 6. Before submission, restart the kernel and run all cells from the beginning.
#
# A validation cell is expected to fail while its task is incomplete.

# %% [markdown]
# ## Practicum outcomes
#
# - execute basic Python statements and calculate with variables;
# - store several numeric observations in a list;
# - select actions with branches and repeat actions with loops;
# - clean, split, validate, and format strings;
# - combine these skills to scan a production log.

# %% [markdown]
# # Module 1: Python Fundamentals and Introduction to Data Structures
#
# ## Brief review
# Python executes statements written in a code cell. `print()` displays a value. Variables give names to values, and operators create new values. A list stores several related values in order.

# %%
print("Hello, World!")

# %%
# Complete example: values, variables, calculations, and output
product_name = "Steel Bracket"
quantity = 40
unit_cost = 12_500
total_cost = quantity * unit_cost

print(f"Product: {product_name}")
print(f"Quantity: {quantity}")
print(f"Total cost: Rp{total_cost:,}")

assert total_cost == 500_000

# %%
# Complete example: one list stores four related observations.
period_output = [120, 135, 128, 142]
period_output[0] = 125
period_output.append(130)

print(period_output)
print(f"Periods: {len(period_output)}")
print(f"Total: {sum(period_output)}")

assert period_output == [125, 135, 128, 142, 130]

# %% [markdown]
# ## Guided completion: first production calculation
#
# Required results:
# - `total_output` is morning plus afternoon output;
# - `difference` is total output minus the target;
# - `average_output` is total output divided by periods.

# %%
morning_output = 125
afternoon_output = 140
daily_target = 250

total_output = 0       # TODO
difference = 0         # TODO
average_output = 0.0   # TODO

print(f"Total: {total_output}")
print(f"Difference: {difference:+d}")
print(f"Average: {average_output:.1f}")

# %%
# Validation: do not modify this cell.
assert total_output == 265, "Check the addition for total_output."
assert difference == 15, "Subtract daily_target from total_output."
assert average_output == 132.5, "Divide total_output by two."
print("Guided Module 1 checks passed.")

# %% [markdown]
# ## Task 1: Daily Production Calculator
#
# ### Requirements
#
# - Use `sum(period_output)` for the total.
# - Use `len(period_output)` for the number of periods.
# - Calculate the average from the total and period count.
# - Calculate actual total minus the daily target.
# - Create the exact report string shown by the validation cell.

# %%
period_output = [120, 135, 128, 142]
daily_target = 500

period_count = 0       # TODO
total_output = 0       # TODO
average_output = 0.0   # TODO
target_difference = 0  # TODO
production_report = ""  # TODO

print(production_report)

# %%
# Validation: do not modify this cell.
assert period_count == 4
assert total_output == 525
assert average_output == 131.25
assert target_difference == 25
assert production_report == (
    "Total=525; Average=131.25; Difference=+25"
)
print("Easy Task 1 checks passed.")

# %% [markdown]
# ### Module 1 checkpoint
#
# Why is one list more suitable than four separate variables for the four period outputs?
#
# **Your answer:**

# %% [markdown]
# # Module 2: Basic Branching and Iteration
#
# ## Brief review
#
# An `if` statement runs code only when a condition is true. `elif` and `else` add alternative paths. A `for` loop processes items from a list, while a `while` loop repeats while its condition remains true.

# %%
# Complete example: classify one result.
actual_units = 480
target_units = 500

if actual_units > target_units:
    status = "ABOVE TARGET"
elif actual_units == target_units:
    status = "ON TARGET"
else:
    status = "BELOW TARGET"

print(status)
assert status == "BELOW TARGET"

# %%
# Complete example: counter and accumulator patterns.
daily_output = [480, 510, 495, 525]
target_units = 500
successful_days = 0
total_output = 0

for units in daily_output:
    total_output += units
    if units >= target_units:
        successful_days += 1

assert successful_days == 2
assert total_output == 2010
print(f"Successful days: {successful_days}")

# %% [markdown]
# ## Guided completion: controlled counter
#
# The starter code is safe to run. Set it so the loop stores `[1, 2, 3, 4, 5]`.

# %%
counter = 1
limit =  # TODO
counted_values = []

while counter <= limit:
    counted_values.append(counter)
    counter += 1

print(counted_values)

# %%
# Validation: do not modify this cell.
assert counted_values == [1, 2, 3, 4, 5]
assert counter == 6
print("Guided Module 2 checks passed.")

# %% [markdown]
# ## Task 2: Production Target Tracker
#
# Process `daily_output` from left to right.
#
# ### Rules
#
# - Stop when the value is `-1`. Ignore all later values.
# - Ignore other negative values.
# - Store one classification for each accepted value.
# - Use `ABOVE TARGET`, `ON TARGET`, or `BELOW TARGET`.
# - Count accepted days and days that reach or exceed the target.
# - Add accepted values to `total_output`.

# %%
daily_output = [480, 500, 525, -4, 510, -1, 600]
daily_target = 500

classifications = []
processed_days = 0
successful_days = 0
total_output = 0

for units in daily_output:
    # TODO: implement the sentinel, invalid-value, counting,
    # classification, and accumulation rules.
    pass

# %%
# Validation: do not modify this cell.
assert classifications == [
    "BELOW TARGET",
    "ON TARGET",
    "ABOVE TARGET",
    "ABOVE TARGET",
]
assert processed_days == 4
assert successful_days == 3
assert total_output == 2015
print("Easy Task 2 checks passed.")

# %% [markdown]
# ### Module 2 checkpoint
#
# What is the difference between `break` and `continue` in the target tracker?
#
# **Your answer:**

# %% [markdown]
# # Module 3: Basic String Manipulation
#
# ## Brief review
#
# Strings store text. Indexing selects one character, slicing extracts a substring, and string methods return cleaned or transformed strings. `split()` creates a list of fields, while `join()` combines strings.

# %%
# Complete example: inspect and clean one string.
raw_label = "  hydraulic   pump  "
words = raw_label.split()
clean_label = " ".join(words).title()
code_label = "-".join(words).upper()

assert clean_label == "Hydraulic Pump"
assert code_label == "HYDRAULIC-PUMP"
assert raw_label == "  hydraulic   pump  "
print(code_label)

# %% [markdown]
# ## Guided completion: normalize a location label
#
# Convert the raw text to `LINE-A-ASSEMBLY`. Remove surrounding whitespace, combine repeated internal whitespace, convert letters to uppercase, and join words with hyphens.

# %%
raw_location = "  line   a   assembly  "

location_words = []     # TODO
standard_location = ""  # TODO

print(standard_location)

# %%
# Validation: do not modify this cell.
assert location_words == ["line", "a", "assembly"]
assert standard_location == "LINE-A-ASSEMBLY"
print("Guided Module 3 checks passed.")

# %% [markdown]
# ## Task 3: Product Code Cleaner
#
# The raw record format is `product name | item number | production line`.
#
# ### Requirements
#
# - Split the record at each pipe character.
# - Require exactly three fields.
# - Normalize the product name to uppercase words separated by hyphens.
# - Require a digit-only item number.
# - Pad the item number to three positions.
# - Normalize the line name to title case with single spaces.
# - Store `INVALID RECORD` if validation fails.
# - Otherwise produce `TSI-PRODUCT-NNN | Line Name`.

# %%
raw_record = "  hydraulic   pump | 24 | line a  "

fields = []       # TODO
product_code = ""  # TODO: replace with validated processing logic.

print(product_code)

# %%
# Validation: do not modify this cell.
assert fields == ["  hydraulic   pump ", " 24 ", " line a  "]
assert product_code == "TSI-HYDRAULIC-PUMP-024 | Line A"
print("Easy Task 3 checks passed.")

# %% [markdown]
# ### Module 3 checkpoint
#
# Why must the program check `len(fields)` before using `fields[0]`, `fields[1]`, and `fields[2]`?
#
# **Your answer:**

# %% [markdown]
# # Final Task: Production Line Log Challenge
#
# This challenge combines calculations, a list, branches, loops, and string processing. The syntax remains basic. The difficulty comes from tracking several pieces of state correctly.
#
# ## Input format
#
# `production_log` is one comma-separated string. Each valid record contains:
#
# - one status letter: `G` for good, `D` for defective, or `R` for reworked;
# - one positive integer quantity.
#
# Example: `G12,D3,G8,R2`.

# %% [markdown]
# ## Processing rules
#
# 1. Split the log at commas and process records from left to right.
# 2. Remove surrounding whitespace and convert each record to uppercase.
# 3. A record is invalid when it has fewer than two characters, has an unsupported status, has a non-digit quantity, or has a quantity below one.
# 4. Add valid quantities to `good_units`, `defective_units`, or `reworked_units`.
# 5. A `G` record extends the current continuous good run by its quantity.
# 6. A `D`, `R`, or invalid record resets the current good run to zero.
# 7. Track the largest value reached by the current good run.
# 8. The target is `REACHED` when total good units are at least `production_target`. Otherwise it is `NOT REACHED`.
# 9. Construct the exact report required by the validation cell.

# %%
production_log = "G12, G8, D3, G5, X4, G10, G7, R2, G9"
production_target = 50

records = production_log.split(",")
good_units = 0
defective_units = 0
reworked_units = 0
invalid_records = 0
current_good_run = 0
longest_good_run = 0

for raw_record in records:
    # TODO: normalize and validate one record.
    # TODO: update counts and continuous-run state.
    pass

target_status = ""  # TODO
final_report = ""   # TODO

print(final_report)

# %%
# Validation: do not modify this cell.
assert good_units == 51
assert defective_units == 3
assert reworked_units == 2
assert invalid_records == 1
assert longest_good_run == 20
assert target_status == "REACHED"
assert final_report == (
    "GOOD=51; DEFECTIVE=3; REWORK=2; INVALID=1; "
    "LONGEST_GOOD_RUN=20; TARGET=REACHED"
)
print("Final task checks passed.")

# %% [markdown]
# ## Manual edge-case checks
#
# After the main validation passes, replace only the input values and run the final task again.
#
# | Production log | Target | Expected observation |
# | --- | ---: | --- |
# | `G5,G4,G3` | 10 | Longest good run is 12; target reached |
# | `D2,R3` | 1 | Good units are 0; target not reached |
# | `G0,G-2,A4,,G5` | 5 | Four invalid records; final good run is 5 |
# | `g2, g3` | 6 | Good units are 5 after normalization; target not reached |
